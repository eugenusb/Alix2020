# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import re
import lightgbm as lgb
import datetime as dt
from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)

# %%
from sklearn.impute import SimpleImputer
from sklearn import svm

# %%
borrar = ["Opportunity_Name", "ID", "Brand", "Product_Type", "ASP_converted_Currency", 
          "Prod_Category_A", "Product_Category_B", "Actual_Delivery_Date", "Last_Activity", 
          "ASP_converted_Currency", "Prod_Category_A", "Product_Name", "Delivery_Year", "Month", 
          "TRF", "Product_Family", "Account_Name"]

useless = ["Submitted_for_Approval", "Account_Type", "Delivery_Terms", "Size", "Price", "ASP_Currency", 
           "Total_Amount_Currency", "Total_Taxable_Amount_Currency","Quote_Type", "Opportunity_Type"] # "Product_Category_B", "Region"]

dates = ["Account_Created_Date", "Opportunity_Created_Date", "Quote_Expiry_Date", "Last_Modified_Date", 
         "Planned_Delivery_Start_Date", "Planned_Delivery_End_Date"]

target = ["Opportunity_ID", "Stage", "Sales_Contract_No"]

# %%
def preprocess(data):
    
    # elimino caracteres prohibidos en los headers
    
    data = data.rename(columns = lambda x:re.sub("[^A-Za-z0-9_]+", "", x))
        
    for d in dates:
        data[d] = pd.to_datetime(data[d])

    # agrego features
    
    data["Contacts"] = data.groupby("Opportunity_ID", sort = False)["Opportunity_ID"].transform("count")
    data["Delivery_Difference"] = (data["Planned_Delivery_End_Date"] - data["Planned_Delivery_Start_Date"]).dt.days
    data["Same_Owner"] = (data.Opportunity_Owner == data.Account_Owner) & (data.Opportunity_Owner == data.Last_Modified_By)
    data["Has_Brand"] = data.Brand != "None"
    data["Has_Contract"] = data.Sales_Contract_No != "None"
    data["Different_Country"] = (data.Billing_Country != data.Territory) & (data.Territory != "None")    
    data.loc[data.TRF == 0, "TRF_Cat"] = 0
    data.loc[(1 <= data.TRF) & (data.TRF <= 7), "TRF_Cat"] = 1
    data.loc[data.TRF > 7, "TRF_Cat"] = 2
    data["Sales"] = data.groupby("Account_Name", sort = False)["Account_Name"].transform("count")
    
    data["Concrete_Offer"] = (data["Planned_Delivery_End_Date"] - data["Opportunity_Created_Date"]).dt.days
    
    data["Offer_Duration"] = (data["Quote_Expiry_Date"] - data["Opportunity_Created_Date"]).dt.days
    
    # fabri
    
    data["Territory_Defined"] = data.Territory != "None"
    data["Past_Quote"] = (data["Last_Modified_Date"] - data["Quote_Expiry_Date"]).dt.days
    
    # casteo a categoricas varias columnas
    categorical = [x for x in data.columns if data[x].dtype == "object"]
    for c in categorical:       
        data[c] = data[c].astype('category')
        
    # limpio columnas
    
    data = data.drop(borrar + useless + dates, axis = 1)
    
    #data.drop(data[(data.Contacts > 1) & (data.ASP.isna())].index, inplace = True)
    #data = data.drop_duplicates([x for x in data.columns if x != 'ID'])
    
    return (data)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelBinarizer

# %%
data = pd.read_csv("Entrenamieto_ECI_2020.csv")

# %%
rest = [x for x in data.columns if x != 'ID']
len(data[data.duplicated(rest)])/float(len(data)) * 100
# Out:
# 2.643535729037588

# %%
prep = preprocess(data)

# %%
prep = prep[(prep.Stage == "Closed Won") | (prep.Stage == "Closed Lost")]
prep.Stage = prep.Stage.replace({"Closed Won": 1, "Closed Lost": 0})

# %%
prep.isna().any()
# Out:
# Region                              False
# Territory                           False
# PricingDelivery_Terms_Quote_Appr    False
# PricingDelivery_Terms_Approved      False
# Bureaucratic_Code_0_Approval        False
# Bureaucratic_Code_0_Approved        False
# Bureaucratic_Code                   False
# Source                              False
# Billing_Country                     False
# Opportunity_ID                      False
# Sales_Contract_No                   False
# Account_Owner                       False
# Opportunity_Owner                   False
# Currency                            False
# Last_Modified_By                    False
# ASP                                  True
# ASP_converted                        True
# Delivery_Quarter                    False
# Total_Amount                         True
# Total_Taxable_Amount                False
# Stage                               False
# Contacts                            False
# Delivery_Difference                  True
# Same_Owner                          False
# Has_Brand                           False
# Has_Contract                        False
# Different_Country                   False
# TRF_Cat                             False
# Sales                               False
# Concrete_Offer                       True
# Offer_Duration                       True
# Territory_Defined                   False
# Past_Quote                           True
# dtype: bool

# %%
prep.drop(["Past_Quote", "Offer_Duration", "Concrete_Offer"], axis = 1, inplace = True)

# %%
cat_vars = [x for x in prep.select_dtypes('category').columns if x != 'Stage']

# %%
label_enc = LabelEncoder()

# %%
for col in cat_vars:
    prep[col] = label_enc.fit_transform(prep[col])

# %%
imputer = SimpleImputer(strategy='mean')

# %%
cols = prep.columns

# %%
cols
# Out:
# Index([u'Region', u'Territory', u'PricingDelivery_Terms_Quote_Appr', u'PricingDelivery_Terms_Approved', u'Bureaucratic_Code_0_Approval', u'Bureaucratic_Code_0_Approved', u'Bureaucratic_Code', u'Source', u'Billing_Country', u'Opportunity_ID', u'Sales_Contract_No', u'Account_Owner', u'Opportunity_Owner', u'Currency', u'Last_Modified_By', u'ASP', u'ASP_converted', u'Delivery_Quarter', u'Total_Amount', u'Total_Taxable_Amount', u'Stage', u'Contacts', u'Delivery_Difference', u'Same_Owner', u'Has_Brand', u'Has_Contract', u'Different_Country', u'TRF_Cat', u'Sales', u'Territory_Defined'], dtype='object')

# %%
prep = imputer.fit_transform(prep)

# %%
prep
# Out:
# array([[ 2., 46.,  1., ...,  2., 63.,  0.],
#        [ 2., 46.,  0., ...,  0., 63.,  0.],
#        [ 1., 43.,  0., ...,  0., 91.,  1.],
#        ...,
#        [ 2.,  3.,  1., ...,  0.,  3.,  1.],
#        [ 1., 42.,  1., ...,  1.,  2.,  1.],
#        [ 1., 42.,  1., ...,  2.,  9.,  1.]])

# %%
prep = pd.DataFrame(prep, columns = cols)

# %%
x_train, x_test, y_train, y_test = train_test_split(prep, prep.Stage, test_size = 0.3, random_state = 0)

# %%
model = svm.SVC(random_state = 42, probability = True, gamma = 'scale', kernel = 'poly', degree = 3)

# %%
model.fit(X = x_train.drop(target, axis = 1), y = y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='scale', kernel='poly',
#   max_iter=-1, probability=True, random_state=42, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred = model.predict_proba(x_test.drop(target, axis = 1))

# %%
y_pred
# Out:
# array([[0.42844157, 0.57155843],
#        [0.42844158, 0.57155842],
#        [0.42844158, 0.57155842],
#        ...,
#        [0.42844158, 0.57155842],
#        [0.42844155, 0.57155845],
#        [0.42844159, 0.57155841]])

# %%
for x in res[:10]:
    print("{:f}".format(x))
# Out:
# 0.652177
# 0.658534
# 0.653449
# 0.657376
# 0.629896
# 0.655262
# 0.609040
# 0.646850
# 0.623969
# 0.653479

# %%
x_test.Stage.head(10)
# Out:
# 2040     0.0
# 4069     0.0
# 4230     1.0
# 578      1.0
# 12594    0.0
# 6042     1.0
# 2763     0.0
# 15900    0.0
# 2669     1.0
# 12802    0.0
# Name: Stage, dtype: float64

# %%
fuck = [x for x in res if x >= 0.025 and x <= 0.95]
len(fuck)
# Out:
# 5065

# %%
len(fuck)/float(len(res)) * 100
# Out:
# 100.0

# %%
pred = pd.DataFrame(res, index = x_test.index, columns = ["Prediction"])

# %%
x_test_pred = x_test.join(pred)
answer = x_test_pred.groupby("Opportunity_ID")["Stage","Prediction"].mean()

# %%
log_loss(answer["Stage"], answer["Prediction"])
# Out:
# 0.64503430109244

# %%
predictors = [x for x in x_train.drop(target, axis = 1).columns]
feat_imp = pd.Series(model.feature_importances_, predictors).sort_values(ascending = False)
feat_imp = feat_imp[0:28]
plt.rcParams['figure.figsize'] = 28, 5
feat_imp.plot(kind = 'bar', title = 'Feature Importance')

# %%
bad = x_test_pred[(x_test_pred.Prediction > 0.5) & (x_test_pred.Stage == 0) | (x_test_pred.Prediction < 0.5) & (x_test_pred.Stage == 1)]

# %%
bad
# Out:
#          Region       Territory  PricingDelivery_Terms_Quote_Appr  PricingDelivery_Terms_Approved  Bureaucratic_Code_0_Approval  Bureaucratic_Code_0_Approved    Bureaucratic_Code     Source Billing_Country  Opportunity_ID Sales_Contract_No   Account_Owner Opportunity_Owner Currency Last_Modified_By      ASP  ASP_converted Delivery_Quarter  Total_Amount  Total_Taxable_Amount  Stage  Contacts  Delivery_Difference  Same_Owner  Has_Brand  Has_Contract  Different_Country  TRF_Cat  Sales  Concrete_Offer  Offer_Duration  Territory_Defined  Past_Quote  Prediction
# 7812       APAC       Australia                                 1                               0                             1                             0  Bureaucratic_Code_5       None       Australia            4832              2252  Person_Name_43    Person_Name_19     None   Person_Name_47   0.5400        0.38211               Q4     109620.00             109620.00      0         1                  7.0       False      False          True              False      0.0    317           181.0           130.0               True       131.0    0.969321
# 4773       APAC           India                                 1                               1                             1                             1  Bureaucratic_Code_4  Source_13       Sri Lanka            2824               904  Person_Name_49    Person_Name_49     None   Person_Name_47   0.3600        0.36000               Q4     157172.40             157172.40      0         1                 19.0       False      False          True               True      0.0     31            72.0            72.0               True       -27.0    0.996730
# 9545       EMEA         Germany                                 0                               0                             0                             0  Bureaucratic_Code_4   Source_9         Germany            6045              None  Person_Name_13    Person_Name_13     None   Person_Name_47   0.4200        0.47506               Q3      30450.00              82700.00      1         2                  4.0       False      False         False              False      0.0    125            32.0             4.0               True       160.0    0.365609
# 9800       APAC        Thailand                                 0                               0                             0                             0  Bureaucratic_Code_4   Source_
americas      NW America                                 0                               0                             0                             0  Bureaucratic_Code_4       None   United States            6630              3172   Person_Name_8     Person_Name_8     None   Person_Name_47      NaN            NaN               Q4       3000.00              94350.00      0         2                  2.0       False      False          True               True      0.0      2            36.0             2.0               True       131.0    0.981309
# 8941   Americas      Central US                                 0                               0                             0                             0  Bureaucratic_Code_4   Source_7   United States            5569              2745  Person_Name_45    Person_Name_48     None   Person_Name_47   0.3900        0.39000               Q4     159120.00             396238.50      0         2                  0.0       False      False          True               True      0.0     29            97.0             NaN               True         NaN    0.683619
# 5603       EMEA           Spain                                 1                               1                             1                             1  Bureaucratic_Code_4   Source_7           Spain            3428              1137  Person_Name_42    Person_Name_39     None   Person_Name_23   0.3800        0.42982               Q4      72675.00              72675.00      0         1                  3.0       False      False          True              False      0.0    127            17.0             3.0               True        91.0    0.955796
# 5606       EMEA           Spain                                 1                               1                             1                             1  Bureaucratic_Code_4   Source_7           Spain            3430              1138  Person_Name_42    Person_Name_39     None   Person_Name_23   0.3800        0.42982               Q1      72675.00              72675.00      0         1                  7.0       False      False          True              False      0.0    127            34.0             3.0               True        91.0    0.980377
# 12164      EMEA         Belgium                                 0                               0                             0                             0  Bureaucratic_Code_4       None     Netherlands            7405              3768  Person_Name_18    Person_Name_18     None   Person_Name_18   0.3600        0.40719               Q1      48600.00              73693.75      0         2                  9.0        True      False          True               True      0.0    144            16.0             4.0               True        26.0    0.687887
# 10105     Japan            None                                 1                               1                             0                             0  Bureaucratic_Code_4       None           Japan            6357              3307  Person_Name_50    Person_Name_50     None   Person_Name_47      NaN            NaN               Q4    1200000.00            4348535.00      0         5                  0.0       False      False          True              False      0.0   2124            26.0             0.0              False       111.0    0.522724
# 6738       EMEA          Poland                                 1                               1                             0                             0  Bureaucratic_Code_4       None          Poland            4166              2110   Person_Name_4     Person_Name_4     None   Person_Name_47   0.3700        0.41850               Q2      22061.25              89891.25      0         3                  4.0       False      False          True              False      0.0     20            32.0            15.0               True       275.0    0.751153
# 8369   Americas      SE America                                 0                               0                             0                             0  Bureaucratic_Code_4   Source_7   United States            5243              2529  Person_Name_33    Person_Name_46     None   Person_Name_47   0.4000        0.40000               Q3      79800.00              79800.00      0         1                  0.0       False      False          True               True      0.0     73            24.0            31.0               True       202.0    0.796563
# 12143  Americas            None                                 1                               0                             1                             0  Bureaucratic_Code_5       None   United States            7392              3763  Person_Name_45    Person_Name_64     None   Person_Name_64      NaN            NaN               Q2       1500.00             227544.00      0         2                  0.0       False      False          True              False      0.0     54           108.0            11.0              False       181.0    0.829546
# 13704      EMEA         Belgium                                 1                               1                             1                             1  Bureaucratic_Code_4       None         Belgium            8357              None  Person_Name_18    Person_Name_18     None   Person_Name_18   0.3350        0.37892               Q2      70350.00             141037.50      1         2                  0.0        True      False         False              False      0.0     40            37.0            37.0               True        -2.0    0.355001
# 9399   Americas      Central US                                 0                               0                             0                             0  Bureaucratic_Code_4  Source_13   United States            5930              2953   Person_Name_3    Person_Name_48     None   Person_Name_47   0.4250        0.42500               Q4      48386.25              48386.25      0         1                  0.0       False      False          True               True      0.0      2           100.0            14.0               True       162.0    0.907174
# 13629  Americas      NW America                                 1                               1                             1                             1  Bureaucratic_Code_4       None   United States            8295              None   Person_Name_8     Person_Name_8     None    Person_Name_8   0.5150        0.51500               Q2     115360.00             118307.00      1         2                  4.0        True      False         False               True      0.0     52             7.0             NaN               True         NaN    0.208483
# 11088      EMEA         Germany                                 0                               0                             0                             0  Bureaucratic_Code_4   Source_
# 14960     Japan            None                                 1                               1                             0                             0  Bureaucratic_Code_4       None           Japan            9368              None  Person_Name_50    Person_Name_50     None   Person_Name_50  55.0000        0.49447               Q4     287100.00             305100.00      1         2                  0.0        True      False         False              False      0.0    355            97.0             0.0              False        87.0    0.188340
# 6999      Japan            None                                 1                               1                             0                             0  Bureaucratic_Code_4       None           Japan            4295              2091  Person_Name_50    Person_Name_50     None   Person_Name_47      NaN            NaN               Q2       4400.00             435720.00      0         5                  0.0       False      False          True              False      0.0   2124             6.0             0.0              False       275.0    0.549322
# 13630  Americas      NW America                                 1                               1                             1                             1  Bureaucratic_Code_4       None   United States            8295              None   Person_Name_8     Person_Name_8     None    Person_Name_8      NaN            NaN               Q2       2947.00             118307.00      1         2                  4.0        True      False         False               True      0.0     52             7.0             NaN               True         NaN    0.302132
# 14903  Americas      NE America                                 0                               0                             0                             0  Bureaucratic_Code_4   Source_9   United States            9320              4866  Person_Name_64    Person_Name_64     None   Person_Name_64   0.4550        0.45500               Q4      10337.60              10737.60      0         2                  0.0        True      False          True               True      0.0     18            34.0            29.0               True         6.0    0.862008
# 7      Americas      NW America                                 1                               1                             1                             1  Bureaucratic_Code_4   Source_7   United States               7              None  Person_Name_64     Person_Name_8     None    Person_Name_8   0.4800        0.48000               Q1      50688.00              50688.00      1         1                  0.0       False      False         False               True      0.0     91            47.0            29.0               True       -29.0    0.044280
# 7656       EMEA     Netherlands                                 0                               0                             0                             0  Bureaucratic_Code_4   Source_7     Netherlands            4723              3589  Person_Name_18    Person_Name_18     None   Person_Name_18   0.4300        0.48637               Q1      90300.00              90300.00      0         1                 85.0        True      False          True              False      0.0     50           191.0            86.0               True        67.0    0.865627
# 14787      EMEA         Denmark                                 1                               1                             1                             1  Bureaucratic_Code_4   Source_7         Germany            9199              None  Person_Name_13    Person_Name_13     None   Person_Name_13   0.2800        0.31671               Q4     309750.00             359310.00      1         2                 16.0        True      False         False               True      1.0    249            76.0            36.0               True        -1.0    0.064667
# 9476   Americas      Central US                                 0                               0                             0                             0  Bureaucratic_Code_4   Source_7   United States            5999              2984   Person_Name_3     Person_Name_3     None    Person_Name_6   0.5030        0.50300               Q4     252757.50             252757.50      0         1                  0.0       False      False          True               True      1.0     13            79.0             6.0               True       283.0    0.796443
# 8514       APAC       Singapore                                 1                               1                             1                             1  Bureaucratic_Code_4       None       Singapore            5330              2613  Person_Name_65    Person_Name_44     None   Person_Name_47   0.3400        0.34000               Q3      79968.00              79968.00      0         1                 14.0       False      False          True              False      0.0      1            34.0            95.0               True       131.0    0.987790
# 12666  Americas      NW America                                 0                               0                             0                             0  Bureaucratic_Code_4       None   United States            7666              3908  Person_Name_45    Person_Name_64     None   Person_Name_64   0.5150        0.51500               Q2     415759.50             419259.50      0         2                  0.0       False      False          True               True      1.0     54           114.0            14.0               True       -13.0    0.603990
# 14838  Americas      NW America                                 0                               0                             0                             0  Bureaucratic_Code_4   Source_7   United States            9250              4834  Person_Name_64    Person_Name_64     None   Person_Name_64   0.4850        0.48500               Q3      10330.50              10805.50      0         2                  0.0        True      False          True               True      0.0    101            18.0             8.0               True        27.0    0.928273
# 12868  Americas      NW America                                 1                               0                             1                             0  Bureaucratic_Code_5   Source_9   United States            7803              3964  Person_Name_64    Person_Name_64     None   Person_Name_64      NaN            NaN               Q2       1700.00              73362.50      0         2                  0.0        True      False          True               True      0.0     12            76.0             6.0               True       154.0    0.972216
# 6505   Americas      SE America                                 0                               0                             0                             0  Bureaucratic_Code_4       None   United States
                 0                               0                             0                             0  Bureaucratic_Code_4   Source_7           Italy            9373              5253   Person_Name_2     Person_Name_2     None    Person_Name_2   0.3100        0.35064               Q4      70122.00              70122.00      0         1                  4.0        True      False          True              False      0.0      3            66.0            85.0               True       -22.0    0.964236
# 11880      EMEA           Spain                                 1                               1                             0                             0  Bureaucratic_Code_4   Source_9           Spain            7255              4133  Person_Name_42    Person_Name_23     None    Person_Name_2   0.3700        0.41850               Q2       4995.00               4995.00      0         1                  4.0       False      False          True              False      0.0      2            10.0            20.0               True         7.0    0.990963
# 16729      EMEA         Denmark                                 0                               0                             0                             0  Bureaucratic_Code_4   Source_9         Germany           12702              None  Person_Name_13    Person_Name_13     None   Person_Name_13   0.5300        0.59948               Q1     310050.00             310050.00      1         1                 39.0        True      False         False               True      1.0    283           112.0            55.0               True       -16.0    0.326417
# 16931      EMEA  United Kingdom                                 1                               1                             0                             0  Bureaucratic_Code_4       None         Germany           12794              None   Person_Name_4     Person_Name_4     None    Person_Name_4   0.5150        0.58251               Q1    2209350.00            2209350.00      1         1                 18.0        True      False         False               True      1.0     76            98.0             7.0               True         0.0    0.422913
# 12128  Americas      NW America                                 1                               0                             1                             0  Bureaucratic_Code_5       None   United States            7385              3756  Person_Name_45    Person_Name_64     None   Person_Name_64      NaN            NaN               Q1       4000.00             519970.00      0         2                 11.0       False      False          True               True      0.0     54           399.0            12.0               True       328.0    0.574461
# 12869  Americas      NW America                                 1                               0                             1                             0  Bureaucratic_Code_5   Source_9   United States            7803              3964  Person_Name_64    Person_Name_64     None   Person_Name_64   0.4550        0.45500               Q3      71662.50              73362.50      0         2                 30.0        True      False          True               True      0.0     12           190.0             6.0               True       154.0    0.960887
# 11012  Americas      NW America                                 1                               1                             0                             0  Bureaucratic_Code_4   Source_7   United States            6793              3568  Person_Name_64    Person_Name_64     None   Person_Name_47   0.5100        0.51000               Q4      21420.00              21420.00      1         1                365.0       False      False          True               True      0.0     91           380.0             9.0               True        56.0    0.499396
# 12665  Americas      NW America                                 0                               0                             0                             0  Bureaucratic_Code_4       None   United States            7666              3908  Person_Name_45    Person_Name_64     None   Person_Name_64      NaN            NaN               Q2       3500.00             419259.50      0         2                  0.0       False      False          True               True      0.0     54           114.0            14.0               True       -13.0    0.677156

# %%
bad.Stage.value_counts()
# Out:
# 0    78
# 1    21
# Name: Stage, dtype: int64

# %%
validation_file = "Validacion_ECI_2020.csv"
vali = pd.read_csv(validation_file)
validation = preprocess(vali)
leak = ["Opportunity_ID", "Sales_Contract_No"]
pred = model.predict_proba(validation.drop(leak, axis = 1))[:,1]

# agrupo por Opportunity_ID para dar una sola prediccion por solicitud

pred = pd.DataFrame(pred, index = validation.index, columns = ["Prediction"])
validation = validation.join(pred)

answer = pd.DataFrame(validation.groupby("Opportunity_ID", as_index = False)["Prediction"].mean())

# %%
prev = pd.read_csv("acceptable/submission_23.csv", names=["Opportunity_ID", "Prediction"])
prev["Prediction"].corr(answer["Prediction"])
# Out:
# 0.9966014072053296

# %%
prev = pd.read_csv("acceptable/submission_11.csv")
prev["Prediction"].corr(answer["Prediction"])
# Out:
# 0.993107873090827
